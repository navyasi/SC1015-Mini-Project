# %%
#Qn: find out how differet variables predict the vote_average rating given by audience
# Basic Libraries
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('TMDB_movie_dataset_v11.csv')
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019213 entries, 0 to 1019212
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1019213 non-null  int64
#  1   title                 1019201 non-null  object
#  2   vote_average          1019213 non-null  float64
#  3   vote_count            1019213 non-null  int64
#  4   status                1019213 non-null  object
#  5   release_date          895029 non-null   object
#  6   revenue               1019213 non-null  int64
#  7   runtime               1019213 non-null  int64
#  8   adult                 1019213 non-null  bool
#  9   backdrop_path         285664 non-null   object
#  10  budget                1019213 non-null  int64
#  11  homepage              110177 non-null   object
#  12  imdb_id               576051 non-null   object
#  13  original_language     1019213 non-null  object
# ...

# %%
def remove_columns(df, columns_to_remove):
    
    remaining_columns = [col for col in df.columns if col not in columns_to_remove]
    return df[remaining_columns]


columns_to_remove=['homepage','backdrop_path','production_companies', 'tagline','imdb_id','original_title','spoken_languages','production_countries']
new_df=remove_columns(df,columns_to_remove)

new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019213 entries, 0 to 1019212
# Data columns (total 16 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   id                 1019213 non-null  int64
#  1   title              1019201 non-null  object
#  2   vote_average       1019213 non-null  float64
#  3   vote_count         1019213 non-null  int64
#  4   status             1019213 non-null  object
#  5   release_date       895029 non-null   object
#  6   revenue            1019213 non-null  int64
#  7   runtime            1019213 non-null  int64
#  8   adult              1019213 non-null  bool
#  9   budget             1019213 non-null  int64
#  10  original_language  1019213 non-null  object
#  11  overview           832225 non-null   object
#  12  popularity         1019213 non-null  float64
#  13  poster_path        731629 non-null   object
#  14  genres             639038 non-null   object
# ...

# %%
new_df = new_df[~new_df['status'].isin(['released'])]
columns_to_remove=['status']
new_df=remove_columns(new_df,columns_to_remove)
new_df=new_df.dropna()
new_df
# Out:
#              id                                              title  \
# 0         27205                                          Inception
# 1        157336                                       Interstellar
# 2           155                                    The Dark Knight
# 3         19995                                             Avatar
# 4         24428                                       The Avengers
# ...         ...                                                ...
# 1019177  673489  "Lately, I've Got This Huge Bulge In My Crotch...
# 1019186  673504                                              Kelly
# 1019189  673508  Gang-Banging The Female Announcer In The Offic...
# 1019200  673450         Pappa Lap 'n Verhaal van n pa en sy dogter
# 1019201  673453                      Doctor Who: The Pertwee Years
#
#          vote_average  vote_count release_date     revenue  runtime  adult  \
# 0               8.364       34495   2010-07-15   825532764      148  False
# ...

# %%
new_df['release_year'] = new_df['release_date'].str.extract(r'(\d{4})-\d{2}-\d{2}', expand=False)
new_df['release_year'] = new_df['release_year'].astype(int)
#calc length of chars for the title
new_df['num_chars'] = new_df['title'].str.len()

new_df
# Out:
#              id                                              title  \
# 0         27205                                          Inception
# 1        157336                                       Interstellar
# 2           155                                    The Dark Knight
# 3         19995                                             Avatar
# 4         24428                                       The Avengers
# ...         ...                                                ...
# 1019177  673489  "Lately, I've Got This Huge Bulge In My Crotch...
# 1019186  673504                                              Kelly
# 1019189  673508  Gang-Banging The Female Announcer In The Offic...
# 1019200  673450         Pappa Lap 'n Verhaal van n pa en sy dogter
# 1019201  673453                      Doctor Who: The Pertwee Years
#
#          vote_average  vote_count release_date     revenue  runtime  adult  \
# 0               8.364       34495   2010-07-15   825532764      148  False
# ...

# %%
new_df = new_df.drop(new_df[new_df['budget'] == 0].index)
new_df = new_df.drop(new_df[new_df['revenue'] == 0].index)
new_df = new_df.drop(new_df[new_df['vote_count'] == 0].index)

new_df
# Out:
#              id                                              title  \
# 0         27205                                          Inception
# 1        157336                                       Interstellar
# 2           155                                    The Dark Knight
# 3         19995                                             Avatar
# 4         24428                                       The Avengers
# ...         ...                                                ...
# 344053   197844                                           Old Fish
# 345197   892749    Science Please! : The Wonderful World of Colour
# 345429   824851                                       Saint Joseph
# 345595   892739  Nanna & Lil' Puss Puss in 'Who Calcutta the Ch...
# 347098  1230761                                    Highway to Hell
#
#         vote_average  vote_count release_date     revenue  runtime  adult  \
# 0              8.364       34495   2010-07-15   825532764      148  False
# ...

# %%
new_df.to_csv('newest_dataf.csv')
